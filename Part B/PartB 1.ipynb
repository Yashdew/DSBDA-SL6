# %%
import pandas as pd
import numpy as np
data = pd.read_csv("Datasets\dataset_Facebook.csv",delimiter=';')

# %% [markdown]
# #  Merge Data

# %%
print(data.head())
cols=data[0:3] # extract  first 3 rows index starts at 0
print(cols.head())
index = data.index
print('index is' + str(index))
cols = data.columns
print(data.iloc[3:5]) # extract row 3 & 4
print(data.iloc[:5]) # first 5 rows
print(data.iloc[0:3,1:4])# Three rows and cols from 1 to 3 
print(data.iloc[[2,5,6]]) # display specific rows
print(data.iloc[:,2])# all rows and column no 2
print(data.loc[[2, 4, 5], ['Type', 'Category']])
print('no of cols'+str(len(data.columns)))
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
ldataset = data.iloc[:,0:10]
ldataset[['Paid','Category']]
#print(ldataset.loc[[2,3,4],['Paid','Category']])
rdataset = data.iloc[:,9:20]
print(rdataset.head())
#merge operation on common column
merge_result =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users')
print(merge_result.head())
common_values = ldataset['Lifetime Engaged Users'].isin(rdataset['Lifetime Engaged Users']).value_counts()
print (common_values)
# Out:
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# ...

# %%
leftjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='left')
print ("Left join")
print (leftjoin.head())
rightjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='right')
# Out:
# Left join
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
print(rightjoin.head())
outerjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='outer')
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %%
print(outerjoin.head())
innerjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='inner')
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %% [markdown]
# # # Sort Data

# %%
sorted_data = data.sort_values('Lifetime Post Total Reach') 
print(sorted_data.head(n=3))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 422            102112  Photo         1           3             1         19
# 426            100732  Photo         1           3             7         18
# 432            100732  Photo         1           3             6         17
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 422   0.0                        238                              570
# 426   0.0                        391                              746
# 432   0.0                        452                              726
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 422                     143                      142
# 426                     131                      130
# 432                     186                      184
#
#      Lifetime Post Consumptions  \
# 422                         834
# 426                         766
# 432                         889
#
# ...

# %%
desc_sorted_data = data.sort_values('Lifetime Post Total Reach',ascending=False) 
print(desc_sorted_data.head(n=3))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 463             92186  Photo         3           2             7          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 464   0.0                     158208                           453213
# 463   1.0                     153536                           497910
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
# 464                    2482                     2319
# 463                    1713                     1633
#
#      Lifetime Post Consumptions  \
# 244                        6242
# 464                        3412
# 463                        2493
#
# ...

# %%
data.sort_values('Lifetime Post Total Reach',inplace=True,ascending=False) 
data.sort_index(inplace=True)

# %% [markdown]
# # transposing data

# %%
trans_data = data.T
print(trans_data.head())
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %% [markdown]
# # Melting data to long format

# %% [markdown]
# df = pd.DataFrame({'Name': {0: 'Shubham', 1: 'Prsika', 2: 'Ishwar'},
#                    'Course': {0:'12th', 1: '12th', 2: 'Diploma'},
#                    'Roll No': {0: 1, 1: 2, 2: 3}})
# print(df)
#
# pd.melt(df, id_vars =['Name'], value_vars =['Course'])
# pd.melt(df, id_vars =['Name'], value_vars =['Course', 'Roll No'])
#
# meltdata1 = pd.melt(data,id_vars = ['Type'], value_vars = ['Post Hour'])
# print (meltdata1.head(n=10))
# meltdata2 = pd.melt(data,id_vars = ['Type'], value_vars = ['Post Hour','Post Month'])
# print (meltdata2.tail(n=3))
# meltdata3 = pd.melt(data,id_vars = ['Type'], var_name ='Facebook Metrics', value_vars = ['Post Hour','Post Month'])
# print (meltdata3.head(n=3))

# %% [markdown]
# # Cast long to wide

# %%
longtowide_data=data.pivot_table(index = 'Type', columns='Lifetime Post Total Reach', values='Post Hour',aggfunc = np.mean)
print(longtowide_data.head(n=3))
# Out:
# Lifetime Post Total Reach  238     391     452     584     617     619     \
# Type
# Link                          NaN     NaN     NaN     NaN     NaN     NaN
# Photo                        19.0    18.0    17.0     9.0     7.0     8.0
# Status                        NaN     NaN     NaN     NaN     NaN     NaN
#
# Lifetime Post Total Reach  645     652     659     677     ...  98816   \
# Type                                                       ...
# Link                          NaN     NaN     NaN     NaN  ...     NaN
# Photo                        13.0     8.0     9.0     5.5  ...     2.0
# Status                        NaN     NaN     NaN     NaN  ...     NaN
#
# Lifetime Post Total Reach  100768  105632  109056  122944  128064  139008  \
# Type
# Link                          NaN     NaN     NaN     NaN     NaN     NaN
# Photo                         NaN    14.0     3.0    10.0    14.0     NaN
# Status                        NaN     NaN     NaN     NaN     NaN     NaN
#
# ...
